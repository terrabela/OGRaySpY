# %%
# 2020-12-20
# Batch para espectros do TP e RF de 2019
# Composição e síntese dos códigos: 
# - openGamma_pkl-generation: coleta dos arquivos
# - openGamma_verbose.ipynb : análise dos espectros

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Feb 22 10:40:56 2020

@author: marcelo

ar1:
- array (nx,2), onde:
    nx: n'umero total de picos em todas as escalas
    x: 'indice do picoh
    ar1[x,0]: canal inteiro do pico
    ar1[x,1]: valor da escala
    
xpk:
- lista (nx), onde:
    nx: numero de picos efetivos ap'os an'alise
    x: canal inteiro do pico
    
ypk:
- lista (nx), onde:
    nx: numero de picos efetivos ap'os an'alise (= nx(xpk))
    x: valor da escala

"""

import numpy as np
import numpy.ma as ma  # masked array
import scipy.stats as sta # statistics
from scipy.special import (erf, erfinv)

from numpy import linalg as LA

from spectrum_analysis import (cwt_complete_analysis, gaussian_complete_analysis, cwt_calc_peaks)
from gamma_spectrum_class import (Spec)
####################################
# Para a coleta dos espectros:
import time
from machine_selection import set_screen_size_by_machine
from filebatch_class import (FileBatch)
from pathlib import (Path)
####################################


from bokeh.models import ColumnDataSource, Whisker, Label, LabelSet, MultiLine
from bokeh.palettes import Paired6
from bokeh.plotting import figure, output_file, output_notebook, show
from bokeh.layouts import gridplot, column, row

from bokeh import palettes

# 2020-08-22 Para rodar curve_fit
from gauss_funcs import func_example, func_example_fixed_b
# 2020-09-03 Desativei por enquanto
# import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
# 2020-08-30
from scipy.interpolate import splrep, splev

from scipy.ndimage import label, generate_binary_structure, find_objects, binary_dilation  # 2020-09-03
from numpy.polynomial import Polynomial as P # 2020-09-06 Esta é a nova classe recomendada 

# 2020-09-11
from opengamma_searchfuncs import selectOverlappedPks

# 2019-03-15
# https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html
import pandas as pd
import csv

# %%
# Para espectros CTP 4k
kSigma = 4.0 # Com 3.0 ele pega os grandes degraus Compton, com 4.0 só o da esquerda (retroespalhamento)
aSta = 0.004
bSta = 3.0
kExpand = 1 # Parâmetro para alargar região (inteiro positivo)
# 2020-12-05 Ainda não aprendi a mexer com o smoo... Chutando bem baixo para 4k, altíssima intens
smoo = 0.1 # Tem que ser >= 0.0
yrange = [10**1, 10**6]
# fn2 = '../Ipen/Efluentes-gasosos/Filtros-espectros/2018/CTP/CTP2203-3.Chn'

# %%
fb = FileBatch()
pathPosixName =  '../Ipen/Efluentes-gasosos/Filtros-espectros/2019'
fb.slotSetBatchCHN( pathPosixName )
print (fb.numarqstxt, ' arquivos')
# Out:
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019
# Num de arquivos:        374
#
#
#   arquivos

# %%
lp_posix = [Path(fn).as_posix() for fn in fb.lp]

# %%
all_polys_specs = []
all_specs_names = []
all_specs_LTs = []
all_specs_start_cnt = []
for fn2 in lp_posix:
    spec2 = Spec()
    if spec2.readSp( fn2 ) >= 0:
        print (fn2)
        all_specs_names.append(fn2)
        all_specs_LTs.append(str(spec2.spLVTime))
        all_specs_start_cnt.append(str(spec2.countDatetime))
        counts = spec2.specIO.spCounts
        print(len(counts))
        if (spec2.chancalib.size >= 3) & (spec2.enChcalib.size == spec2.chancalib.size):
            spec2.coeffs_ChEn = P.fit(spec2.chancalib, spec2.enChcalib, deg=2)
        if (spec2.enFwcalib.size >= 3) & (spec2.fwhmcalib.size == spec2.enFwcalib.size):
            spec2.coeffs_EnFw = P.fit(spec2.enFwcalib, spec2.fwhmcalib, deg=2)
        xs = spec2.xs
        y0s = spec2.y0sCorr
        lnCounts = spec2.lnCounts
        nCh = xs.size
        # Calcular espectro com ajuste parabólico na mesma janela e calculado no centro da janela
        parabSpec = np.zeros(nCh)
        hWIni = spec2.hStaW(0,a=aSta,b=bSta)
        hWFin = spec2.hStaW(nCh-1,a=aSta,b=bSta)
        for i in range(hWIni,nCh-hWFin):
            hW = spec2.hStaW(i,a=aSta,b=bSta)
            chanWin = np.array(range(i-hW,i+hW+1))
            lnctsWindow = lnCounts[chanWin]
            # Primeiro, acha usando parábola na janela e calcula no canal central
            parabWinFit = P.fit(chanWin,lnctsWindow,deg=2)
            parabSpec[i]=parabWinFit(i)
        tckDirectSpl = splrep(xs, parabSpec, k=3, s=smoo)
        smooParabSpec = np.exp(splev(xs, tckDirectSpl, der=0))
        del parabSpec
        isRegionSigma = np.abs(y0s-smooParabSpec) / (np.sqrt(y0s+5))
        isReg = isRegionSigma > kSigma
        # 2020-12-06
        # Expandindo canais marcados para chExpand = kExpand * hStaW(ch) canais antes e depois
        # Deu certo: depois, eliminar chExpand fixo.
        isRegExpand = np.zeros(nCh)
        chExpandIni = kExpand*spec2.hStaW(0,a=aSta,b=bSta)
        chExpandFin = kExpand*spec2.hStaW(nCh-1,a=aSta,b=bSta)
        for i in range(chExpandIni, nCh-chExpandFin+1):
            chExpandMov = kExpand*spec2.hStaW(i,a=aSta,b=bSta)
            isRegExpand[i] = np.any(isReg[i-chExpandMov:i+chExpandMov+1])
        # Com base nos canais marcados, definir extremos das regiões
        comuta = np.zeros(nCh)
        for i in range(1,nCh):
            comuta[i] = isRegExpand[i] - isRegExpand[i-1]
        # inis = np.insert(np.nonzero(comuta>0), 0, 0)
        # np.nonzero gera uma tupla, não sei por quê.
        inis = np.nonzero(comuta>0)[0]
        # fins = np.append(np.nonzero(comuta<0), n)
        fins = np.nonzero(comuta<0)[0]
        # Ajusta comprimento dos arrays. Têm de ser iguais.
        minSize = np.minimum(inis.size, fins.size)
        inis = inis[:minSize] 
        fins = fins[:minSize]
        mix = np.concatenate(np.array([[inis], [fins]])).T
        # Agora, criar nova baseline onde
        # Fora das regiões marcadas, seja smooParabSpec
        # Nas regiões marcadas, seja a stepLine dos extremos
        assembledBaseLine = np.array(smooParabSpec)
        for regLim in mix:
            assembledBaseLine[regLim[0]:regLim[1]+1] = spec2.stepBaseLine (
                regLim[0], regLim[1], smooParabSpec[regLim[0]], smooParabSpec[regLim[1]], y0s)
        lnNetCounts = np.zeros(nCh)
        wLnNetCounts = np.zeros(nCh)
        uncys = np.sqrt(y0s)
        contin = assembledBaseLine
        yNets = y0s - contin
        for i in range(nCh):
            if yNets[i] < 2:
                lnNetCounts[i] = 0
                wLnNetCounts[i] = 0
            else:
                lnNetCounts[i] = np.log(yNets[i])
                wLnNetCounts[i] = np.sqrt(y0s[i])
        # 2020-12-16
        # Usando as regiões mix, ir direto ao ajuste parabólico
        # Quebrar yNets usando mix
        # Testar se é uma gaussiana simples ou multipleto
        # 2020-12-16  Agora vou usar split para dividir o array. Vejamos:
        # 2020-12-18 AQUI: 1e-3 picota demais. Usar:
        cutFactor = 1e-5
        # Ok. Agora, montando tudo: e acrescentando os canais xs correpondentes, e também uncys
        xsUsefulSubRegions = []
        usefulSubRegions = []
        wsUsefulSubRegions = []
        for regLim in mix:
            # print('===============')
            xsNetReg = xs[regLim[0]:regLim[1]]
            netRegion = yNets[regLim[0]:regLim[1]]
            #  wsNetReg = uncys[regLim[0]:regLim[1]]  # Nao bom com uncys. Tentar com:
            netRegion[netRegion < 0.0] = 0.0
            wsNetReg = netRegion
            maxCountInReg = np.max(netRegion)
            isToSplit = (netRegion / maxCountInReg) < cutFactor
            comuta = np.zeros(isToSplit.size)
            for i in range(1,isToSplit.size):
                comuta[i] = isToSplit[i] ^ isToSplit[i-1]
            splitting, = comuta.nonzero() # Precisa da vírgula pois é tupla
            xsSplitted = np.split(xsNetReg,splitting)
            splitted = np.split(netRegion,splitting)
            wsSplitted = np.split(wsNetReg,splitting)
            # print(splitted)
            # print('-----')
            # for i in range(0,len(splitted),2):
            #     print(splitted[i])
            # for j in range(1,len(splitted),2):
            #     print(splitted[j])
            if not isToSplit[0]:
                xsUsefulSubRegions.append(xsSplitted[0])
                usefulSubRegions.append(splitted[0])
                wsUsefulSubRegions.append(wsSplitted[0])
            for i in range(splitting.size):
                if not isToSplit[splitting[i]]:
                    xsUsefulSubRegions.append(xsSplitted[i+1])
                    usefulSubRegions.append(splitted[i+1])
                    wsUsefulSubRegions.append(wsSplitted[i+1])
        newregsMarks = [np.ones_like(x)*1.0e4 for x in xsUsefulSubRegions]
        xspolys = []
        polys = []
        for ixs, xsreg in enumerate(xsUsefulSubRegions):
            ysreg=usefulSubRegions[ixs]
            wsreg=wsUsefulSubRegions[ixs]
            if xsreg.size > 2:
                xspolys.append(xsreg)
                polys.append(P.fit(xsreg,np.log(ysreg),w=wsreg,deg=2))
        # 2020-12-18
        # PAREI AQUI: Agora, partir direto para o cálculo dos picos a partir de polys
        # Está tudo na list polys
        # 2020-12-20 Depois de calcular polys, montar o np.array dos picos e
        # Salvar num csv usando numpy.savetxt
        all_polys_specs.append(polys)
# Out:
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0205-2.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP2401-3.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0702-1.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1212-2 (7,31%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP2811-2 (7,31%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0507.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP2609-2 (9,26%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP11073.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1001-2.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1807.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP3005-3 (7,86%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0310-2 (10,05%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP2401-5.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0512-2 (5,33%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1909-3 (6,70%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP2908-2 (7,57%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP2401-2.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0702.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1005-3.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1411-2 (6,78%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP2401.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1508-4 (7,67%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP2401-4.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1010-4 (9,54%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0711-3 (7,72%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1306-2 (7,07%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP2504-3 (3,26%) (tb no Det LoBG).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0310-3 (5,46%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0102-2.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP2111-3 (9,17%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP2305-3 (7,75%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP2706-2.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1906-2 (4,70%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0509-3 (8,10%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP3110-3 (10,05%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1701.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1605-2 (7,53%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1209-3 (5,31%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1005-2 (10,67%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP2410-3 (6,14%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0808-2.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1001.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1701-2.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0606-2 (7,77%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP2507-2.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0102.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0108-2.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0509-2 (10,76%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP2612-2 5ks (5,31%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1912-2 (6,90%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP2111-2 (9,91%)(Descons).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1710-3 (8,33%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP2208-3 (6,39%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1402.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0102-3.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0301.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP1701-3.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1306-1 (12,58%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP0509-1 (19,42%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1912-1 (28.72%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP0310-1 (17,64%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP3005-2 (12,32%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP0205-1 (28,86%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP2612-2 (7,54%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1209-1 (16,6%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1107-1 (28,44%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP2802-1.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1912-2 (6,92%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1710 (38%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1807-1 (12,08%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1909-2 (12,56%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP0509-2 (10,76%) 5 ks.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP2305-1 (43,80%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1010-3 (18,10%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP2410-2 (11,24%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1508-2 (27,10%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP16051.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP2305-2 (20,44%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP0512-1 (14,2%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP2102-1.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1411-1 (11,46%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP0808-1.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP100519-1.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP2208-2 (11,88%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP 19 6 19 100s.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP2208-1 (19,5%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1909-1 (22,02%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1212-1 (13,52%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP0711-1 (23,28%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP0507-1 (9,26%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP0606_100s.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1508-1(36,5%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP0711-2 (12,96%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1107-2 (12,38%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1402-1.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP3110-3 (10,06%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP3110-1 (33,44%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP2908-1 (14,6%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1209-2 (12,46%) 100s.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1508-3 (14,30%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP2410 (19.5%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP3110-2 (19,14%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1010-2 (34,54%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP2609-1 (16,32%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1010-4 (9,56%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP 250719 100s.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP2102-2.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP3005_1.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP2811-1 (11,44%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP0108-1.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP2111-2 (9,92%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP2111-1 (15,92%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1010-1 (412,72%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP2706.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP2612-1.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP2111-3 (9,22%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP0102-3.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/t_morto/CTP1710-2 (15,34%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN1107.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN1710.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN0310.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN1411.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN2208.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN2507.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN3110.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN1701.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN0606.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN1306.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN2706.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN3101.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN2802.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN1906.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN2811.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN2111.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN2305.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN1402.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN0509.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN1001.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN2609.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN0301.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN1912.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN1005.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN1010.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN2102.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN2410.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN0808.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN0205.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN3005.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN1605.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN1209.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN0108.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN0507.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN0512.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN2908.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN0711.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN1508.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN0702.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN0703.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN1807.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN1212.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN1909.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN2401.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crn/CRN2612.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN1807.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN1212.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN2401.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN2706.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN0108.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN2410.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN1010.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN2507.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN3005.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN1411.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN1909.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN2811.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN3110.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN1306.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN2208.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN1001.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN1701.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN1508.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN0808.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN0606.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN0512.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN0703.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN2305.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN2908.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN0301.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN2802.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN0310.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN2609.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN0507.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN1402.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN0711.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN2102.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN0509.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN1005.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN3101.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN1605.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN2111.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN1906.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN1912.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN1710.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN1107.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN2612.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN0702.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN2811-Rep.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pnr/PRN1209.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI0608.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI3008-F.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI0210-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI1112-I (com plaqueta).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI0711-F.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI2108-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI1010-F.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI2808-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI2607.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI2108-F.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI3007.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI1109-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI1112-I (sem plaqueta).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI1311-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI2507F.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI0910-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI1907F.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI2310-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI1610-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI1812-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI0506F.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI0409-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI0611-I123.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI1405F.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Pci/PCI1809-I123.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP1209.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP2908.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP0702.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP0507.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP1906.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP2305.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP1710.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP1701.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP2102.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP2811-Rep.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP0301.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP2208.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP1010.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP0108.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP0703.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP0512.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP1402.chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP1605.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP1807.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP2609.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP0808.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP2401.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP3110.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP2612.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP0102.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP0711.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP0310.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP0606.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP1212.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP2811.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP1001.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP2706.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP2410.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP1306.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP2410 rep.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP2507.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP1107.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP1508.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP1005.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP2111.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP1912.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP3005.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP0509.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP1909.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ptp/PTP1411.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF2507.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF1909.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF2802.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF3101.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF2401.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF1402.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF1001.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF2305.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF1107.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF3005.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF1701.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF1209.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF2102.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF0509.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF0702.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF1005.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF1508.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF1807.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF0507.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF2706.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF1306.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF2609.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF1010.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF0808.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF1605.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF0205.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF2208.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF0310 (rep)(seria p CALIB energia no Maestro).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF0606.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF0301.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF1710.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF0310.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF1906.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF0108.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Crf/CRF2908.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI0711-F.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI1112-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI1610-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI1809-I 123.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI2310-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI2108-F.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI2507F.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI1311-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI1010-F.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI2108-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI0210-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI0611-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI1109-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI2808-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI0210-I (Rep)...(DESCONSID).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI0506F (22,13%).Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/cci3007.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI0608.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI1907F.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI1812-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI1405F.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI0506F-2.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI2607.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI0910-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI0409-I.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Cci/CCI3008-F.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF1001.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF1209.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF2802.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF1306.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF1906.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF2401.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF1605.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF0301.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF1010.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF2706.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF0509.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF2305.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF1807.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF2208.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF0703-ruim-2.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF1710.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF3005.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF3101.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF0108.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF0808.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF1402.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF0703-ruim.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF2908.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF2609.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF0702.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF2507.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF1909.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF0507.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF1107.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF1701.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF2102.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF0310.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF1005.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF1508.Chn
# 4096
# ../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF0606.Chn
# 4096

# %%
numSpe = len(all_specs_names)
print(numSpe)
results_areas = np.empty([numSpe,13],dtype=object)
results_areas
# Out:
# 374
# array([[None, None, None, ..., None, None, None],
#        [None, None, None, ..., None, None, None],
#        [None, None, None, ..., None, None, None],
#        ...,
#        [None, None, None, ..., None, None, None],
#        [None, None, None, ..., None, None, None],
#        [None, None, None, ..., None, None, None]], dtype=object)

# %%
all_spec_pEns = []
spec2 = Spec()
for fn2 in all_specs_names:
    if spec2.readSp( fn2 ) >= 0:
        all_spec_pEns.append(spec2.pEn)
# Tem que ter o mesmo len de all_specs_names!
print(len(all_spec_pEns))
# Out:
# 374

# %%
# Constante para cálculo da área do pico
karea = 0.5*np.sqrt(np.pi/np.log(2.0))

for ipEn, pols_in_a_spec in enumerate(all_polys_specs):
    polys_conv = []
    for pol in pols_in_a_spec:
        polconv = pol.convert().coef
        if polconv[2] < 0:
            polys_conv.append(polconv)
    polys_conv_ar = np.array(polys_conv)
    linha = np.empty(13,dtype=object)
    linha[0]=all_specs_names[ipEn]
    linha[1]=all_specs_LTs[ipEn].replace('.',',')
    linha[2]=all_specs_start_cnt[ipEn]
    if polys_conv_ar.shape[0]!=0:
        a0 = polys_conv_ar[:,0]
        a1 = polys_conv_ar[:,1]
        a2 = polys_conv_ar[:,2]
        sigmas = 1.0/(np.sqrt(2*(-a2)))
        fwhms = 2*np.sqrt(2*np.log(2))*sigmas
        chCentroids = -a1/(2*a2)
        alturas = np.exp(a0 - a1**2 / (4*a2))
        areas = karea * alturas * fwhms
        max5 = np.argsort(areas)[-5:]
        maxareas = np.array(areas[max5])
        enCtroids = all_spec_pEns[ipEn](chCentroids)
        maxens = enCtroids[max5]
        # AQUI para posicionar direito em linha:
        nmaxar = maxareas.shape[0]
        str1 = np.array([str(x).replace('.',',') for x in maxareas])
        str2 = np.array([str(x).replace('.',',') for x in maxens])
        # Tem que ser 3 para nmaxar==5, 4 para nmaxar==4, etc.
        linha[8-nmaxar:8] = str1
        linha[13-nmaxar:13] = str2
    results_areas[ipEn] = linha

# %%
print(karea)
# Out:
# 1.0644670194312262

# %%
results_areas.shape
# Out:
# (374, 13)

# %%
results_areas
# Out:
# array([['../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0205-2.Chn',
#         '5000,0', '2019-05-17 14:31:23', ..., '632,7443174308075',
#         '286,37681332407146', '365,05817327322427'],
#        ['../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP2401-3.Chn',
#         '5000,0', '2019-02-06 17:24:48', ..., '646,2507536593064',
#         '293,4540367261361', '373,56778043857594'],
#        ['../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Ctp/CTP0702-1.Chn',
#         '5000,0', '2019-02-18 14:45:12', ..., '623,9586766373185',
#         '271,1199689595643', '351,2626869549523'],
#        ...,
#        ['../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF1005.Chn',
#         '5000,0', '2019-05-10 14:36:14', ..., None, None,
#         '-18,454522654393703'],
#        ['../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF1508.Chn',
#         '5000,0', '2019-08-15 15:00:36', ..., None, None, None],
#        ['../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF0606.Chn',
#         '5000,0', '2019-06-06 14:00:32', ..., '597,2784476468258',
#         '592,478357411088', '255,07429868631363']], dtype=object)

# %%
# 2020-12-22 E finalmente...

# %%
np.savetxt('2019_TP_RF_results.csv', results_areas, fmt='%s', delimiter=';', newline='\n')

# %%
results_areas[-1]
# Out:
# array(['../Ipen/Efluentes-gasosos/Filtros-espectros/2019/Prf/PRF0606.Chn',
#        '5000,0', '2019-06-06 14:00:32', None, '3,375161783507002',
#        '7,238284290412698', '270,71087367302863', '430,80286593822893',
#        None, '0,8193462853564809', '597,2784476468258',
#        '592,478357411088', '255,07429868631363'], dtype=object)

# %%
### 2020-12-20 FIM!
