# %%
import matplotlib.pyplot as plt
import numpy as np

def my_plotter(ax, data1, data2, param_dict):
    """
    A helper function to make a graph

    Parameters
    ----------
    ax : Axes
        The axes to draw to

    data1 : array
       The x data

    data2 : array
       The y data

    param_dict : dict
       Dictionary of kwargs to pass to ax.plot

    Returns
    -------
    out : list
        list of artists added
    """
    out = ax.plot(data1, data2, **param_dict)
    return out

# which you would then use as:

data1, data2, data3, data4 = np.random.randn(4, 100)
fig1, ax = plt.subplots(1, 1)
# my_plotter(ax, data1, data2, {'marker': 'x', 'linewidth': 0.5, 'color': 'darkred'})
my_plotter(ax, data1, data2, {'linewidth': 0.5, 'color': 'darkred'})

# %%
fig2, (ax1, ax2) = plt.subplots(1, 2)
my_plotter(ax1, data1, data2, {'marker': 'o'})
my_plotter(ax2, data3, data4, {'marker': '+'})

# %%
my_plotter(ax1, data1, data2, {'marker': '.'})

# %%
fig1

# %%
fig2

# %%
fig2

# %%
fig1

# %%
ax2.set_title('Título 2')
# Out:
# Text(0.5,1,'Título 2')

# %%
fig2

# %%
fig2.set_figheight(7.0)

# %% [markdown]
# #### fig2

# %%
fig2.set_figheight(12)

# %%
fig2.set_figwidth(20)

# %%
fig2

# %%
fig2a = fig2

# %%
fig2a

# %%
fig3, ax1 = plt.subplots(1,1)

# %%
fig1

# %%
fig2

# %%
fig3, (ax1, ax2) = plt.subplots(1, 2)
my_plotter(ax1, data1, data2, {'marker': 'o'})
my_plotter(ax2, data3, data4, {'marker': '+'})

# %%
my_plotter(ax1, data1, data2, {'marker': 'o'})
my_plotter(ax2, data3, data4, {'marker': '+'})

# %%
my_plotter(ax5, data1, data2, {'marker': 'o'})
my_plotter(ax6, data3, data4, {'marker': '+'})
fig4, (ax5, ax6) = plt.subplots(1, 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-663c0726587c> in <module>()
# ----> 1 my_plotter(ax5, data1, data2, {'marker': 'o'})
#       2 my_plotter(ax6, data3, data4, {'marker': '+'})
#       3 fig4, (ax5, ax6) = plt.subplots(1, 2)
#
# NameError: name 'ax5' is not defined

# %%
fig4, (ax5, ax6) = plt.subplots(1, 2, figsize=(15,5))
my_plotter(ax5, data1, data2, {'marker': 'o'})
my_plotter(ax6, data3, data4, {'marker': '+'})

# %%
fig5, ax5 = plt.subplots(1, 1)
my_plotter(ax5, data1, data2, {'marker': 'o'})

# %%
ax5.set_title('Eixo 5')
fig5

# %%
fig4, ax5 = plt.subplots(1, 1)

# %%
ax5.set_title('Eixo 5 novo')
fig5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-7446f2ffd8e4> in <module>()
#       1 ax5.set_title('Eixo 5 novo')
# ----> 2 fig5
#
# NameError: name 'fig5' is not defined

# %%
fig5, ax5 = plt.subplots(1, 1, figsize=(7,7))
my_plotter(ax5, data1, data2, {'marker': 'o'})

# %%
ax5.set_title('Eixo 5 novo')
fig5

# %%
fig5

# %%
fig5(1,figsize=(12,2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-20c3b5620553> in <module>()
# ----> 1 fig5(1,figsize=(12,2))
#
# TypeError: 'Figure' object is not callable

# %%
figsize(12,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-70c16905028f> in <module>()
# ----> 1 figsize(12,2)
#
# NameError: name 'figsize' is not defined

# %%
ax5

# %%
ax6
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-675c093f39a9> in <module>()
# ----> 1 ax6
#
# NameError: name 'ax6' is not defined

# %%
ax2

# %%
fig1

# %%
fig2

# %%
fig3

# %%
fig4

# %%
fig5

# %%
fig4

# %%
fig4.add_subplot(1,3,3)

# %%
fig4

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
# plt.show()

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'og', x1, y1, '-y')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)
plt.plot(x2, y2, '.-r')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

# plt.show()
# Out:
# Text(0,0.5,'Undamped')

# %%
fig7, (ax7a, ax7b) = plt.subplots(1, 2)
my_plotter(ax7a, data1, data2, {'marker': 'o'})
my_plotter(ax7b, data3, data4, {'marker': '+'})

# %%
font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        }

x = np.linspace(0.0, 5.0, 100)
y = np.cos(2*np.pi*x) * np.exp(-x)

plt.plot(x, y, 'k')
plt.title('Damped exponential decay', fontdict=font)
plt.text(2, 0.65, r'$\cos(2 \pi t) \exp(-t)$', fontdict=font)
plt.xlabel('time (s)', fontdict=font)
plt.ylabel('voltage (mV)', fontdict=font)

# Tweak spacing to prevent clipping of ylabel
plt.subplots_adjust(left=0.15)
# plt.show()

# %%
font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        }

x = np.linspace(0.0, 5.0, 100)
y = np.cos(2*np.pi*x) * np.exp(-x)

plt.plot(x, y, 'k')
plt.title('Damped exponential decay', fontdict=font)
plt.text(2, 0.65, r'$\cos(2 \pi t) \exp(-t)$', fontdict=font)
plt.xlabel('time (s)', fontdict=font)
plt.ylabel('voltage (mV)', fontdict=font)

# Tweak spacing to prevent clipping of ylabel
plt.subplots_adjust(left=0.15)

# %%
fig8, ((ax7a, ax7b), (ax1, ax2)) = plt.subplots(2, 2)
my_plotter(ax7a, data1, data2, {'marker': 'o'})
my_plotter(ax7b, data3, data4, {'marker': '+'})
my_plotter(ax1, data1, data2, {'marker': '*'})
my_plotter(ax2, data3, data4, {'marker': '.'})

# %%
fig9, (ax6, ax5) = plt.subplots(2, 1)

# %%
plt.subplots(2, 2)

# %%
fig2, (ax1, ax2) = plt.subplots(1, 2)
my_plotter(ax1, data1, data2, {'marker': 'o'})
my_plotter(ax2, data3, data4, {'marker': '+'})

# %%
arr1, arr2 = np.random.randn(2, 3, 7)

# %%
arr1
# Out:
# array([[-0.12163254, -1.50381491,  1.50757079,  0.23010134,  0.65847586,
#          0.87527257,  0.24444662],
#        [-1.13788062,  2.69632077,  1.17462043,  0.81868828,  0.04696008,
#          1.30258763, -1.11996112],
#        [ 0.65026112,  0.071915  , -0.94319825, -0.43470768, -2.68522982,
#          0.68257959,  2.06569107]])

# %%
arr2
# Out:
# array([[-0.15572038,  1.50271108,  1.11320369, -0.3521376 , -1.26106861,
#          1.67452343, -0.48545366],
#        [ 0.16173334,  0.99600383, -0.93845422, -0.06316664,  0.22208533,
#          0.16306014,  2.15568707],
#        [ 1.28504186,  0.45166749,  1.06659879,  0.88784595, -0.16019274,
#          1.17355309, -0.74638805]])

# %%
arr12 = arr1+arr2

# %%
arr12
# Out:
# array([[-2.77352928e-01, -1.10382122e-03,  2.62077448e+00,
#         -1.22036261e-01, -6.02592752e-01,  2.54979600e+00,
#         -2.41007038e-01],
#        [-9.76147272e-01,  3.69232461e+00,  2.36166207e-01,
#          7.55521636e-01,  2.69045413e-01,  1.46564776e+00,
#          1.03572595e+00],
#        [ 1.93530297e+00,  5.23582486e-01,  1.23400540e-01,
#          4.53138269e-01, -2.84542257e+00,  1.85613267e+00,
#          1.31930302e+00]])

# %%
arr3 = np.random.randn(3,5)

# %%
arr3
# Out:
# array([[ 0.72515589, -0.09509101,  0.02899106, -1.46621397, -0.10257285],
#        [-0.47854066, -1.60186434,  1.29373775, -0.60478489, -0.03278378],
#        [ 0.01686441,  0.5178982 ,  0.73023762,  0.81232936,  1.81146638]])

# %%
list1 = [arr1, arr2, arr3]

# %%
list2 = [arr2, arr1, arr3]

# %%
[a+b for a, b in zip(list1, list2)]
# Out:
# [array([[-2.77352928e-01, -1.10382122e-03,  2.62077448e+00,
#          -1.22036261e-01, -6.02592752e-01,  2.54979600e+00,
#          -2.41007038e-01],
#         [-9.76147272e-01,  3.69232461e+00,  2.36166207e-01,
#           7.55521636e-01,  2.69045413e-01,  1.46564776e+00,
#           1.03572595e+00],
#         [ 1.93530297e+00,  5.23582486e-01,  1.23400540e-01,
#           4.53138269e-01, -2.84542257e+00,  1.85613267e+00,
#           1.31930302e+00]]),
#  array([[-2.77352928e-01, -1.10382122e-03,  2.62077448e+00,
#          -1.22036261e-01, -6.02592752e-01,  2.54979600e+00,
#          -2.41007038e-01],
#         [-9.76147272e-01,  3.69232461e+00,  2.36166207e-01,
#           7.55521636e-01,  2.69045413e-01,  1.46564776e+00,
#           1.03572595e+00],
#         [ 1.93530297e+00,  5.23582486e-01,  1.23400540e-01,
#           4.53138269e-01, -2.84542257e+00,  1.85613267e+00,
#           1.31930302e+00]]),
#  array([[ 1.45031178, -0.19018202,  0.05798212, -2.93242793, -0.2051457 ],
# ...

# %%
list1
# Out:
# [array([[-0.12163254, -1.50381491,  1.50757079,  0.23010134,  0.65847586,
#           0.87527257,  0.24444662],
#         [-1.13788062,  2.69632077,  1.17462043,  0.81868828,  0.04696008,
#           1.30258763, -1.11996112],
#         [ 0.65026112,  0.071915  , -0.94319825, -0.43470768, -2.68522982,
#           0.68257959,  2.06569107]]),
#  array([[-0.15572038,  1.50271108,  1.11320369, -0.3521376 , -1.26106861,
#           1.67452343, -0.48545366],
#         [ 0.16173334,  0.99600383, -0.93845422, -0.06316664,  0.22208533,
#           0.16306014,  2.15568707],
#         [ 1.28504186,  0.45166749,  1.06659879,  0.88784595, -0.16019274,
#           1.17355309, -0.74638805]]),
#  array([[ 0.72515589, -0.09509101,  0.02899106, -1.46621397, -0.10257285],
#         [-0.47854066, -1.60186434,  1.29373775, -0.60478489, -0.03278378],
#         [ 0.01686441,  0.5178982 ,  0.73023762,  0.81232936,  1.81146638]])]

# %%
np.asarray(list1[2])
# Out:
# array([[ 0.72515589, -0.09509101,  0.02899106, -1.46621397, -0.10257285],
#        [-0.47854066, -1.60186434,  1.29373775, -0.60478489, -0.03278378],
#        [ 0.01686441,  0.5178982 ,  0.73023762,  0.81232936,  1.81146638]])
